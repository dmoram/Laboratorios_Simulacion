# %% [markdown]
# # SIMULACIÓN | LABORATORIO 5

# %% [markdown]
# ## Boostrap o remuestreo

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy 
from IPython.display import display, Math
import ipywidgets as widgets
import random
import scipy.stats as stats
import statistics

# %% [markdown]
# ### Ejercicio 1
# En un estudio sobre plantaciones de coihue, se ha recopilado información sobre la altura que alcanzan dichos árboles a los 20 años de edad, en diversas zonas de la región sur austral de Chile. A partir de dichos datos, estamos interesados en calcular un intervalo de confianza para la mediana de altura que alcanza esta especie a los 20 años de edad.
# Para ello utilizaremos remuestreo o bootstrap.
# 1. Analice el código y evalue el número de muestras de bootstrap para alcanzar convergencia de la varianza estimada de la mediana.
# 2. Calcule el error cuadrático medio de la mediana.
# 3. Escoja otro estadístico de la muestra y calcule su incerteza con la técnica de boostrap
# 4. Compare y comente sus resultados.

# %%
datos = [12.5,11.4,18.4,10.7,9.5,11.7,15.4,12.3,18.6, 14.7, 10.7,11.6, 10.1, 8.2, 11.4,21.1, 12.1, 7.5, 12.5, 14.7, 10.3, 5.4, 9.4, 13.8, 9.6, 11.3, 14.8, 12.6]
len(datos)
# Out:
# 28

# %%
n = len(datos)
m = statistics.median(datos)
print (m)
b=100
mm = 0
mn =[]
for i in range(b):
    dat = np.random.choice(list(datos),size=n,replace=True)
    mn.append(statistics.median(dat))
    
var_real = statistics.variance(mn)
print(var_real)
rango = 1.96*math.sqrt(var_real)
display(Math('%0.2f \pm %0.2f' % (m, rango )))
# Out:
# 11.649999999999999
# 0.2993171717171717
# $\displaystyle 11.65 \pm 1.07$

# %% [markdown]
# ### Respuesta

# %% [markdown]
# ### 1.1)

# %%
tol = 1e-3
n = len(datos)
b = 90
idx = 0
dif = 1
conv = False
var_b = []
while(not conv):
    b+=10
    mn =[]
    for i in range(b):
        dat = np.random.choice(list(datos),size=n,replace=True)
        mn.append(statistics.median(dat))
        
    var = statistics.variance(mn)
    print(var)
    var_b.append(var)
    if(idx > 1):
        if((abs(var_b[idx] - var_b[idx-1]) < tol) and (abs(var_b[idx-1] - var_b[idx-2]) < tol)):
            conv = True
    idx+=1    
    
print("La varianza estimada de la mediana converge con un valor de {}".format(var))
print("Se ha alcanzado la convergencia con b = ",b)

# %% [markdown]
# Luego de experimentar con el valor de p, se obtuvo que aproximadamente con un valor de 2810 se logra una convergencia en cuanto a la varianza de la mediana.

# %%
fig, ax = plt.subplots(figsize=(12,8))
x = np.arange(100,b+10,10)
ax.plot(x,var_b, label="Varianza estimada de la mediana")
ax.axhline(y=var, color='r', linestyle='-', label='Punto de convergencia estimado de la mediana')

ax.set_xlabel("Cantidad de muestras")
ax.set_ylabel("Varianza estimada de la mediana")
ax.set_title("Gráfica de convergencia")
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9077/164983594.py in <module>
#       1 fig, ax = plt.subplots(figsize=(12,8))
#       2 x = np.arange(100,b+10,10)
# ----> 3 ax.plot(x,var_b, label="Varianza estimada de la mediana")
#       4 ax.axhline(y=var, color='r', linestyle='-', label='Punto de convergencia estimado de la mediana')
#       5
#
# ~/envs/datascience/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~/envs/datascience/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~/envs/datascience/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499
#     500         if x.shape[0] != y.shape[0]:
# --> 501             raise ValueError(f"x and y must have same first dimension, but "
#     502                              f"have shapes {x.shape} and {y.shape}")
#     503         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (437,) and (366,)

# %% [markdown]
# Se observa que aproximadamente con p = 2810, es decir, 2810 muestras de bootstrap se logra una convergencia de la varianza estimada de la mediana considerando una tolerancia igual a 1e-4.

# %% [markdown]
# ### 1.2)

# %% [markdown]
# Estimación error medio cuadrático.

# %%
err = []
for i in range(b):
    err.append((mn[i] - m)**2) 
mse = sum(err)/b
mse
# Out:
# 0.2510500000000003

# %% [markdown]
# ### 1.3)

# %% [markdown]
# Para el análisis se eligió la curtusis como estadístico.

# %%
b = 100
kurt = stats.kurtosis(datos)
n = len(datos)
print (kurt)
b=100

kurt_list =[]
for i in range(b):
    dat = np.random.choice(list(datos),size=n,replace=True)
    kurt_list.append(stats.kurtosis(dat))
    
var = statistics.variance(kurt_list)
print(var)
rango = 1.96*math.sqrt(var)
display(Math('%0.2f \pm %0.2f' % (kurt, rango )))
# Out:
# 0.6367811949310642
# 0.796882542878727
# $\displaystyle 0.64 \pm 1.75$

# %% [markdown]
# ### Ejercicio 2
#
# Suponga que los datos previamente registrados provienen de una distribución normal de parámetros $(\mu,\sigma)$
#
# 1. Calcule los estimadores máximo verosímil de $\hat{\mu}$ y $\hat{\sigma}$
# 2. Utilice boostrap paramétrico para estimar la incerteza de $\hat{\mu}$ y $\hat{\sigma}$ . Estime el número de muestras para alcanzar convergencia en cada caso.
# 3. Compare y comente sus resultados.

# %% [markdown]
# ### Respuesta

# %% [markdown]
# ### 2.1)

# %%
mu, sigma = stats.norm.fit(datos)

print("Media mu: {}\nDesviación estandar sigma: {}".format(mu, sigma))
# Out:
# Media mu: 12.225000000000003
# Desviación estandar sigma: 3.3405116160766237

# %%
# Estimación de la media mu
tol = 1e-3
b = 90
idx = 0
dif = 1
var_b = []
conv = False
while(not conv):
    b+=10
    mean_list =[]
    for i in range(b):
        dat = np.random.choice(list(datos),size=n,replace=True)
        mean_list.append(statistics.mean(dat))
        
    var = statistics.variance(mean_list)
    var_b.append(var)
   
    if(idx > 1):
        if((abs(var_b[idx] - var_b[idx-1]) < tol) and (abs(var_b[idx-1] - var_b[idx-2]) < tol)):
            conv = True
    idx+=1    
print("Se ha alcanzado la convergencia con b = ",b)
# Out:
# Se ha alcanzado la convergencia con b =  1080

# %%
fig, ax = plt.subplots(figsize=(12,8))
x = np.arange(100,b+10,10)
ax.plot(x, var_b, label="Varianza estimada de la media")
ax.axhline(y=var, color='r', linestyle='-', label='punto de convergencia estimado de la media')
ax.set_xlabel("Cantidad de muestras")
ax.set_ylabel("Varianza estimada de la media")
ax.set_title("Gráfica de convergencia")
ax.legend()

# %%
statistics.mean(mean_list)
# Out:
# 12.212136243386244

# %%
# Estimación de la desviación estandar sigma
tol = 1e-3
b = 90
idx = 0
dif = 1
var_b = []
conv = False
while(not conv):
    b+=10
    desvest_list =[]
    for i in range(b):
        dat = np.random.choice(list(datos),size=n,replace=True)
        desvest_list.append(statistics.pstdev(dat))
       
        
    var = statistics.variance(desvest_list)
    var_b.append(var)
    if(idx > 1):
        if((abs(var_b[idx] - var_b[idx-1]) < tol) and (abs(var_b[idx-1] - var_b[idx-2]) < tol)):
            conv = True
    idx+=1    
print("Se ha alcanzado la convergencia con b = ",b)
# Out:
# Se ha alcanzado la convergencia con b =  1310

# %%
fig, ax = plt.subplots(figsize=(12,8))
x = np.arange(100,b+10,10)
ax.plot(x,var_b)
ax.axhline(y=var, color='r', linestyle='-', label='Varianza real de la media')
ax.set_xlabel("Cantidad de muestras")
ax.set_ylabel("Varianza estimada de la desviación estandar")
ax.set_title("Gráfica de convergencia")
# Out:
# Text(0.5, 1.0, 'Gráfica de convergencia')

# %%
statistics.mean(desvest_list)
# Out:
# 3.228815734974538

# %% [markdown]
# ###  Análisis de los resultados
#
# - Podemos observar que estimando un número de muestras que varía entre 1000-3000 con una tolerancia de 0.001, podemos alcanzar la convergencia tanto para la media  como para la desviación estandar en este caso, coincidiendo con el resultado obtenido calculando los estimadores de máxima verosimilitud para la media y desviación estandar, siendo un mu de 12.225 y un sigma de 3.34 aproximadamente.
